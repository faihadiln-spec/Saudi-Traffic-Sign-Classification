# %% [markdown]
# # **🚦Saudi Traffic Sign Classification**

# %% [markdown]
# ### **1 - Environment Setup**
# Install all required packages and import libraries needed throughout the project.

# %% [markdown]
# **1.1 Install Dependencies**

# %%
pip install -r requirements.txt
# Out:
# Collecting torch (from -r requirements.txt (line 1))
#   Downloading torch-2.11.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting torchvision (from -r requirements.txt (line 2))
#   Downloading torchvision-0.26.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting timm (from -r requirements.txt (line 3))
#   Downloading timm-1.0.26-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: roboflow in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.16)
# Collecting transformers (from -r requirements.txt (line 5))
#   Downloading transformers-5.6.2-py3-none-any.whl.metadata (33 kB)
# Collecting keras-cv (from -r requirements.txt (line 6))
#   Using cached keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scikit-learn in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (3.8.4)
# Requirement already satisfied: seaborn in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: pandas in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (2.3.2)
# Requirement already satisfied: numpy in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.26.4)
# Collecting gradio (from -r requirements.txt (line 12))
#   Downloading gradio-6.13.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: Pillow in c:\users\hayal\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (12.1.1)
# Requirement already satisfied: filelock in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (69.5.1)
# Collecting sympy>=1.13.3 (from torch->-r requirements.txt (line 1))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hayal\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (2024.3.1)
# Requirement already satisfied: pyyaml in c:\users\hayal\anaconda3\lib\site-packages (from timm->-r requirements.txt (line 3)) (6.0.1)
# Collecting huggingface_hub (from timm->-r requirements.txt (line 3))
#   Downloading huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors (from timm->-r requirements.txt (line 3))
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: certifi in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (2024.7.4)
# Requirement already satisfied: idna==3.7 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (3.7)
# Requirement already satisfied: cycler in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (4.10.0.84)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.5.5)
# Requirement already satisfied: python-dateutil in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: requests in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (2.32.2)
# Requirement already satisfied: six in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (4.66.4)
# Requirement already satisfied: requests-toolbelt in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: filetype in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: pi-heif<2 in c:\users\hayal\anaconda3\lib\site-packages (from roboflow->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hayal\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 5)) (23.2)
# Collecting regex>=2025.10.22 (from transformers->-r requirements.txt (line 5))
#   Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 1.0 MB/s eta 0:00:00
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->-r requirements.txt (line 5))
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\users\hayal\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 5)) (0.17.4)
# Requirement already satisfied: absl-py in c:\users\hayal\anaconda3\lib\site-packages (from keras-cv->-r requirements.txt (line 6)) (2.3.1)
# Collecting tensorflow-datasets (from keras-cv->-r requirements.txt (line 6))
#   Using cached tensorflow_datasets-4.9.9-py3-none-any.whl.metadata (11 kB)
# Collecting keras-core (from keras-cv->-r requirements.txt (line 6))
#   Using cached keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Collecting kagglehub (from keras-cv->-r requirements.txt (line 6))
#   Using cached kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hayal\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hayal\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hayal\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hayal\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hayal\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (4.51.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hayal\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hayal\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 10)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hayal\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 10)) (2023.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\hayal\anaconda3\lib\site-packages (from gradio->-r requirements.txt (line 12)) (4.2.0)
# Collecting brotli>=1.1.0 (from gradio->-r requirements.txt (line 12))
#   Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio->-r requirements.txt (line 12))
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting gradio-client==2.5.0 (from gradio->-r requirements.txt (line 12))
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio->-r requirements.txt (line 12))
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio->-r requirements.txt (line 12))
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\hayal\anaconda3\lib\site-packages (from gradio->-r requirements.txt (line 12)) (0.27.0)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\hayal\anaconda3\lib\site-packages (from gradio->-r requirements.txt (line 12)) (2.1.3)
# Collecting orjson~=3.0 (from gradio->-r requirements.txt (line 12))
#   Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\hayal\anaconda3\lib\site-packages (from gradio->-r requirements.txt (line 12)) (2.5.3)
# Collecting pydub<1.0 (from gradio->-r requirements.txt (line 12))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio->-r requirements.txt (line 12))
#   Downloading python_multipart-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio->-r requirements.txt (line 12))
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 12))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=0.40.0 (from gradio->-r requirements.txt (line 12))
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio->-r requirements.txt (line 12))
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting uvicorn>=0.14.0 (from gradio->-r requirements.txt (line 12))
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hayal\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 12)) (1.3.0)
# Collecting pydantic<=3.0,>=2.0 (from gradio->-r requirements.txt (line 12))
#   Downloading pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
#      ---------------------------------------- 0.0/108.8 kB ? eta -:--:--
#      ------------------------- ------------- 71.7/108.8 kB 1.3 MB/s eta 0:00:01
#      ------------------------- ------------- 71.7/108.8 kB 1.3 MB/s eta 0:00:01
#      ------------------------------------ 108.8/108.8 kB 788.2 kB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0,>=0.115.2->gradio->-r requirements.txt (line 12))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio->-r requirements.txt (line 12))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httpcore==1.* in c:\users\hayal\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hayal\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 12)) (0.14.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface_hub->timm->-r requirements.txt (line 3))
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hayal\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio->-r requirements.txt (line 12)) (0.6.0)
# Collecting pydantic-core==2.46.3 (from pydantic<=3.0,>=2.0->gradio->-r requirements.txt (line 12))
#   Downloading pydantic_core-2.46.3-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hayal\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hayal\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\hayal\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hayal\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hayal\anaconda3\lib\site-packages (from typer->transformers->-r requirements.txt (line 5)) (13.3.5)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub->keras-cv->-r requirements.txt (line 6))
#   Downloading kagglesdk-0.1.21-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: namex in c:\users\hayal\anaconda3\lib\site-packages (from keras-core->keras-cv->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: h5py in c:\users\hayal\anaconda3\lib\site-packages (from keras-core->keras-cv->-r requirements.txt (line 6)) (3.11.0)
# Collecting dm-tree (from keras-core->keras-cv->-r requirements.txt (line 6))
#   Downloading dm_tree-0.1.10-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hayal\anaconda3\lib\site-packages (from requests->roboflow->-r requirements.txt (line 4)) (2.0.4)
# Collecting etils>=1.9.1 (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Downloading etils-1.14.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting immutabledict (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Using cached immutabledict-4.3.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting promise (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Using cached promise-2.3-py3-none-any.whl
# Requirement already satisfied: protobuf>=3.20 in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (6.33.0)
# Requirement already satisfied: psutil in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: pyarrow in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (14.0.2)
# Collecting simple_parsing (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Using cached simple_parsing-0.1.8-py3-none-any.whl.metadata (8.1 kB)
# Collecting tensorflow-metadata (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Using cached tensorflow_metadata-1.17.3-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: termcolor in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: toml in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: wrapt in c:\users\hayal\anaconda3\lib\site-packages (from tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (1.14.1)
# Collecting einops (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Using cached einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: zipp in c:\users\hayal\anaconda3\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv->-r requirements.txt (line 6)) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\hayal\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hayal\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers->-r requirements.txt (line 5)) (2.15.1)
# Requirement already satisfied: attrs>=18.2.0 in c:\users\hayal\anaconda3\lib\site-packages (from dm-tree->keras-core->keras-cv->-r requirements.txt (line 6)) (23.1.0)
# Collecting docstring-parser~=0.15 (from simple_parsing->tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting googleapis-common-protos<2,>=1.56.4 (from tensorflow-metadata->tensorflow-datasets->keras-cv->-r requirements.txt (line 6))
#   Downloading googleapis_common_protos-1.74.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hayal\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer->transformers->-r requirements.txt (line 5)) (0.1.0)
# Downloading torch-2.11.0-cp312-cp312-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/114.6 MB 6.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.1/114.6 MB 6.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.2/114.6 MB 1.5 MB/s eta 0:01:18
#    ---------------------------------------- 0.3/114.6 MB 1.8 MB/s eta 0:01:06
#    ---------------------------------------- 0.4/114.6 MB 1.8 MB/s eta 0:01:04
#    ---------------------------------------- 0.5/114.6 MB 2.0 MB/s eta 0:00:59
#    ---------------------------------------- 0.7/114.6 MB 2.1 MB/s eta 0:00:56
#    ---------------------------------------- 0.8/114.6 MB 2.1 MB/s eta 0:00:55
#    ---------------------------------------- 0.9/114.6 MB 2.1 MB/s eta 0:00:54
#    ---------------------------------------- 1.0/114.6 MB 2.1 MB/s eta 0:00:55
#    ---------------------------------------- 1.2/114.6 MB 2.2 MB/s eta 0:00:52
#    ---------------------------------------- 1.2/114.6 MB 2.2 MB/s eta 0:00:51
#    ---------------------------------------- 1.3/114.6 MB 2.2 MB/s eta 0:00:52
#    ---------------------------------------- 1.3/114.6 MB 2.1 MB/s eta 0:00:54
#    ---------------------------------------- 1.4/114.6 MB 2.0 MB/s eta 0:00:57
MB 10.4 MB/s eta 0:00:02
#    -------------------------------- ------- 94.2/114.6 MB 9.4 MB/s eta 0:00:03
#    --------------------------------- ------ 95.1/114.6 MB 10.4 MB/s eta 0:00:02
#    --------------------------------- ------ 95.8/114.6 MB 11.1 MB/s eta 0:00:02
#    --------------------------------- ------ 96.4/114.6 MB 10.9 MB/s eta 0:00:02
#    --------------------------------- ------ 96.4/114.6 MB 10.1 MB/s eta 0:00:02
#    --------------------------------- ------ 97.3/114.6 MB 9.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 98.2/114.6 MB 11.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 99.0/114.6 MB 11.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 99.3/114.6 MB 10.9 MB/s eta 0:00:02
#    ---------------------------------- ---- 100.1/114.6 MB 12.1 MB/s eta 0:00:02
#    ---------------------------------- ---- 101.3/114.6 MB 12.4 MB/s eta 0:00:02
#    ---------------------------------- ---- 101.4/114.6 MB 12.4 MB/s eta 0:00:02
#    ---------------------------------- ---- 101.4/114.6 MB 12.4 MB/s eta 0:00:02
#    ---------------------------------- ---- 102.0/114.6 MB 11.3 MB/s eta 0:00:02
#    ----------------------------------- --- 103.2/114.6 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- --- 103.8/114.6 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- --- 103.8/114.6 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- --- 104.1/114.6 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- --- 104.8/114.6 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- --- 105.7/114.6 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ -- 106.5/114.6 MB 12.3 MB/s eta 0:00:01
#    ------------------------------------ -- 106.7/114.6 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ -- 106.8/114.6 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ -- 107.7/114.6 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ -- 108.6/114.6 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- - 109.0/114.6 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- - 109.0/114.6 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- - 109.4/114.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- - 110.2/114.6 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- - 110.8/114.6 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- - 111.3/114.6 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- - 111.3/114.6 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 111.4/114.6 MB 9.9 MB/s eta 0:00:01
#    --------------------------------------  112.0/114.6 MB 10.7 MB/s eta 0:00:01
#    --------------------------------------  112.8/114.6 MB 10.7 MB/s eta 0:00:01
#    --------------------------------------  113.5/114.6 MB 10.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  114.4/114.6 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  114.4/114.6 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    --------------------------------------  114.6/114.6 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 7.9 MB/s eta 0:00:00
# Downloading torchvision-0.26.0-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.3 MB 25.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.3 MB 20.7 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 21.0 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 21.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.4/4.3 MB 10.8 MB/s eta 0:00:01
#    ------------------------------ --------- 3.2/4.3 MB 12.0 MB/s eta 0:00:01
#    ------------------------------------- -- 4.0/4.3 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 12.3 MB/s eta 0:00:00
# Downloading timm-1.0.26-py3-none-any.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 16.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 19.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 18.3 MB/s eta 0:00:00
# Downloading transformers-5.6.2-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.9/10.4 MB 18.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/10.4 MB 18.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.4 MB 18.8 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.4 MB 18.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.9/10.4 MB 12.2 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/10.4 MB 13.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.4/10.4 MB 13.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.1/10.4 MB 13.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.7/10.4 MB 14.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.0/10.4 MB 12.9 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.4 MB 13.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.4 MB 13.2 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.4 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.4 MB 13.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.3/10.4 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  10.1/10.4 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 13.4 MB/s eta 0:00:00
# Using cached keras_cv-0.9.0-py3-none-any.whl (650 kB)
# Downloading gradio-6.13.0-py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.7 MB 16.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.5/19.7 MB 16.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.5/19.7 MB 18.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.5/19.7 MB 18.0 MB/s eta 0:00:01
#    ------ --------------------------------- 3.1/19.7 MB 13.2 MB/s eta 0:00:02
#    -------- ------------------------------- 4.1/19.7 MB 14.5 MB/s eta 0:00:02
#    --------- ------------------------------ 4.8/19.7 MB 15.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 5.2/19.7 MB 15.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 5.2/19.7 MB 15.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 5.9/19.7 MB 12.9 MB/s eta 0:00:02
#    ------------- -------------------------- 6.8/19.7 MB 13.7 MB/s eta 0:00:01
#    --------------- ------------------------ 7.7/19.7 MB 14.0 MB/s eta 0:00:01
#    --------------- ------------------------ 7.7/19.7 MB 14.0 MB/s eta 0:00:01
#    --------------- ------------------------ 7.7/19.7 MB 11.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.5/19.7 MB 12.1 MB/s eta 0:00:01
#    ------------------- -------------------- 9.5/19.7 MB 12.9 MB/s eta 0:00:01
#    -------------------- ------------------- 10.3/19.7 MB 13.1 MB/s eta 0:00:01
#    -------------------- ------------------- 10.3/19.7 MB 13.1 MB/s eta 0:00:01
#    --------------------- ------------------ 10.4/19.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 11.2/19.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 12.1/19.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 13.1/19.7 MB 12.8 MB/s eta 0:00:01
#    -------------------------- ------------- 13.1/19.7 MB 12.8 MB/s eta 0:00:01
#    -------------------------- ------------- 13.1/19.7 MB 12.8 MB/s eta 0:00:01
#    -------------------------- ------------- 13.2/19.7 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.8/19.7 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.4/19.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------ --------- 15.2/19.7 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 15.9/19.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 15.9/19.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 16.2/19.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 17.1/19.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 18.1/19.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.7 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.7 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.8/19.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.7 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.7/19.7 MB 9.9 MB/s eta 0:00:00
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/60.0 kB ? eta -:--:--
#    ---------------------------------------- 60.0/60.0 kB 3.1 MB/s eta 0:00:00
# Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl (369 kB)
#    ---------------------------------------- 0.0/369.1 kB ? eta -:--:--
#    --------------------------------------- 369.1/369.1 kB 22.4 MB/s eta 0:00:00
# Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.7 kB ? eta -:--:--
#    ---------------------------------------- 117.7/117.7 kB 6.7 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
#    ---------------------------------------- 0.0/646.8 kB ? eta -:--:--
#    --------------------------------------  645.1/646.8 kB 20.5 MB/s eta 0:00:01
#    --------------------------------------- 646.8/646.8 kB 20.5 MB/s eta 0:00:00
# Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl (127 kB)
#    ---------------------------------------- 0.0/127.4 kB ? eta -:--:--
#    ---------------------------------------- 127.4/127.4 kB 3.7 MB/s eta 0:00:00
# Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
#    ---------------------------------------- 0.0/472.0 kB ? eta -:--:--
#    --------------------------------------- 472.0/472.0 kB 14.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.46.3-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------- ---------------- 1.2/2.1 MB 26.7 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 18.9 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.8 kB ? eta -:--:--
#    ---------------------------------------- 277.8/277.8 kB 8.6 MB/s eta 0:00:00
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
#    ---------------------------------------- 0.0/341.4 kB ? eta -:--:--
#    --------------------------------------- 341.4/341.4 kB 10.7 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.7 kB ? eta -:--:--
#    ---------------------------------------- 72.7/72.7 kB ? eta 0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------- ----------------------------- 0.7/2.7 MB 23.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.7 MB 22.8 MB/s eta 0:00:01
#    ------------------------------------ --- 2.5/2.7 MB 22.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.5/2.7 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 11.6 MB/s eta 0:00:00
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.9 kB ? eta -:--:--
#    ---------------------------------- ----- 61.4/70.9 kB ? eta -:--:--
#    ---------------------------------------- 70.9/70.9 kB 1.3 MB/s eta 0:00:00
# Using cached kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Using cached keras_core-0.1.7-py3-none-any.whl (950 kB)
# Using cached tensorflow_datasets-4.9.9-py3-none-any.whl (5.3 MB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading etils-1.14.0-py3-none-any.whl (172 kB)
#    ---------------------------------------- 0.0/172.9 kB ? eta -:--:--
#    --------------------------------------- 172.9/172.9 kB 10.2 MB/s eta 0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/3.7 MB 18.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.7 MB 17.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.4/3.7 MB 19.4 MB/s eta 0:00:01
#    --------------------------- ------------ 2.5/3.7 MB 17.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.5/3.7 MB 17.7 MB/s eta 0:00:01
#    ------------------------------ --------- 2.8/3.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 10.7 MB/s eta 0:00:00
# Downloading kagglesdk-0.1.21-py3-none-any.whl (212 kB)
#    ---------------------------------------- 0.0/212.7 kB ? eta -:--:--
#    --------------------------------------- 212.7/212.7 kB 13.5 MB/s eta 0:00:00
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading dm_tree-0.1.10-cp312-cp312-win_amd64.whl (112 kB)
#    ---------------------------------------- 0.0/112.7 kB ? eta -:--:--
#    ---------------------------------------- 112.7/112.7 kB 6.4 MB/s eta 0:00:00
# Using cached immutabledict-4.3.1-py3-none-any.whl (5.0 kB)
# Using cached simple_parsing-0.1.8-py3-none-any.whl (113 kB)
# Using cached tensorflow_metadata-1.17.3-py3-none-any.whl (31 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.7 kB ? eta -:--:--
#    ---------------------------------------- 300.7/300.7 kB 9.1 MB/s eta 0:00:00
# Using cached einops-0.8.2-py3-none-any.whl (65 kB)
# Installing collected packages: pydub, brotli, typing-inspection, tomlkit, sympy, semantic-version, safetensors, regex, python-multipart, pydantic-core, promise, orjson, immutabledict, hf-xet, groovy, googleapis-common-protos, etils, einops, docstring-parser, dm-tree, annotated-doc, uvicorn, torch, tensorflow-metadata, starlette, simple_parsing, pydantic, kagglesdk, torchvision, safehttpx, keras-core, kagglehub, fastapi, huggingface_hub, tokenizers, timm, gradio-client, transformers, tensorflow-datasets, hf-gradio, keras-cv, gradio
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.10.3
#     Uninstalling regex-2023.10.3:
#       Successfully uninstalled regex-2023.10.3
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed annotated-doc-0.0.4 brotli-1.2.0 dm-tree-0.1.10 docstring-parser-0.18.0 einops-0.8.2 etils-1.14.0 fastapi-0.136.1 googleapis-common-protos-1.74.0 gradio-6.13.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.4.3 huggingface_hub-1.12.0 immutabledict-4.3.1 kagglehub-1.0.0 kagglesdk-0.1.21 keras-core-0.1.7 keras-cv-0.9.0 orjson-3.11.8 promise-2.3 pydantic-2.13.3 pydantic-core-2.46.3 pydub-0.25.1 python-multipart-0.0.26 regex-2026.4.4 safehttpx-0.1.7 safetensors-0.7.0 semantic-version-2.10.0 simple_parsing-0.1.8 starlette-1.0.0 sympy-1.14.0 tensorflow-datasets-4.9.9 tensorflow-metadata-1.17.3 timm-1.0.26 tokenizers-0.22.2 tomlkit-0.14.0 torch-2.11.0 torchvision-0.26.0 transformers-5.6.2 typing-inspection-0.4.2 uvicorn-0.46.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.

# %% [markdown]
# **1.2 Import Libraries**

# %%
from roboflow import Roboflow
import torch
import torch.nn as nn
import torch.nn.functional as F
import timm
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np
import os
import copy
import random
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import gradio as gr
from PIL import Image

# %% [markdown]
# ### **2 - Dataset**
# Download the Saudi Traffic Sign Dataset from Roboflow. The dataset is pre-processed and augmented, containing 24 traffic sign classes split into train / validation / test sets.

# %%
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("hayas-workspace-vivrw").project("saudi-traffic-sign-dataset")
version = project.version(2)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Saudi-Traffic-Sign-Dataset-2 to folder:: 100%|██████████| 100617/100617 [00:07<00:00, 13139.34it/s]
# Extracting Dataset Version Zip to Saudi-Traffic-Sign-Dataset-2 in folder:: 100%|██████████| 7536/7536 [00:00<00:00, 10329.45it/s]

# %% [markdown]
# ### **3 - Configuration & Reproducibility**
# Define all hyperparameters in one place for easy tuning, and fix random seeds to ensure reproducible results.

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 25
LEARNING_RATE = 1e-4
NUM_CLASSES = 24
DATASET_DIR = dataset.location

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ### **4 - Data Preprocessing & DataLoaders**
# Apply standard ImageNet normalization transforms and create DataLoaders for train, validation, and test splits.

# %%
transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(os.path.join(DATASET_DIR, "train"), transform=transform)
val_dataset   = datasets.ImageFolder(os.path.join(DATASET_DIR, "valid"), transform=transform)
test_dataset  = datasets.ImageFolder(os.path.join(DATASET_DIR, "test"),  transform=transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

CLASS_NAMES = train_dataset.classes
print(f"Classes: {len(CLASS_NAMES)}")
print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")
# Out:
# Classes: 24
# Train: 6055 | Val: 807 | Test: 672

# %% [markdown]
# ### **5 - Model Definitions**
# Build four pretrained transformer models using the `timm` library. All models are initialized with ImageNet weights and their classification heads are replaced with a 'NUM_CLASSES' output layer.
#
# | Model        | Architecture                           |
# |:-------------|:---------------------------------------|
# | ViT          | `vit_base_patch16_224`                 |
# | Swin         | `swin_base_patch4_window7_224`         |
# | MobileViT    | `mobilevit_s`                          |
# | EfficientViT | `efficientvit_b1`                      |

# %%
def build_model(model_name, num_classes):
    model = timm.create_model(model_name, pretrained=True, num_classes=num_classes)
    return model.to(DEVICE)

models_to_train = {
    "ViT":    build_model("vit_base_patch16_224", NUM_CLASSES),
    "Swin":  build_model("swin_base_patch4_window7_224", NUM_CLASSES),
    "MobileViT":  build_model("mobilevit_s", NUM_CLASSES),
    "EfficientViT": build_model("efficientvit_b1", NUM_CLASSES)
}

print("All models built:")
for name, model in models_to_train.items():
    params = sum(p.numel() for p in model.parameters()) / 1e6
    print(f"  {name}: {params:.1f}M parameters")
# Out:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/22.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/36.5M [00:00<?, ?B/s]
# All models built:
#   ViT: 85.8M parameters
#   Swin: 86.8M parameters
#   MobileViT: 5.0M parameters
#   EfficientViT: 7.5M parameters

# %% [markdown]
# ### **6 - Model Training**
# Train each model with:
# - **Optimizer:** AdamW (weight decay = 1e-4)
# - **LR Scheduler:** ReduceLROnPlateau (patience = 3, factor = 0.5)
# - **Loss:** CrossEntropyLoss
# - **Early Stopping:** patience of 7 epochs with no validation improvement
# - **Checkpointing:** Best weights saved to disk after each improvement

# %%
def train_model(name, model, train_loader, val_loader, epochs, lr):
    optimizer = AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = ReduceLROnPlateau(optimizer, patience=3, factor=0.5)
    criterion = nn.CrossEntropyLoss()

    best_acc = 0.0
    best_weights = None
    history = {"train_acc": [], "val_acc": [], "train_loss": [], "val_loss": []}
    no_improve = 0

    for epoch in range(epochs):
        # Train phase
        model.train()
        train_loss, train_correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            train_correct += (outputs.argmax(1) == labels).sum().item()
            total += images.size(0)

        train_acc  = train_correct / total
        train_loss = train_loss / total

        # Val phase
        model.eval()
        val_loss, val_correct, val_total = 0, 0, 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_correct += (outputs.argmax(1) == labels).sum().item()
                val_total += images.size(0)

        val_acc  = val_correct / val_total
        val_loss = val_loss / val_total

        scheduler.step(val_loss)

        # Record history
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)
        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc*100:.2f}% | "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc*100:.2f}%")

        # Save best model and early stopping
        if val_acc > best_acc:
            best_acc = val_acc
            best_weights = copy.deepcopy(model.state_dict())
            torch.save(best_weights, f"/content/{name}_best.pth")
            print(f"  ✅ Best model saved ({best_acc*100:.2f}%)")
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= 7:
                print(f"  ⏹ Early stopping at epoch {epoch+1}")
                break

    # Restore best weights
    model.load_state_dict(best_weights)
    return history

# Train all models
histories = {}
for name, model in models_to_train.items():
    print(f"\n{'='*50}")
    print(f"Training: {name}")
    print(f"{'='*50}")
    histories[name] = train_model(name, model, train_loader, val_loader, EPOCHS, LEARNING_RATE)
    print(f"Finished: {name}")
# Out:
# ==================================================
# Training: ViT
# ==================================================
# Epoch [1/25] Train Loss: 0.4360 Acc: 86.77% | Val Loss: 0.0396 Acc: 99.01%
#   ✅ Best model saved (99.01%)
# Epoch [2/25] Train Loss: 0.0662 Acc: 97.90% | Val Loss: 0.1413 Acc: 95.91%
# Epoch [3/25] Train Loss: 0.0713 Acc: 98.07% | Val Loss: 0.0535 Acc: 98.39%
# Epoch [4/25] Train Loss: 0.0348 Acc: 98.94% | Val Loss: 0.0274 Acc: 99.50%
#   ✅ Best model saved (99.50%)
# Epoch [5/25] Train Loss: 0.0440 Acc: 98.60% | Val Loss: 0.0222 Acc: 99.38%
# Epoch [6/25] Train Loss: 0.0016 Acc: 99.97% | Val Loss: 0.0139 Acc: 99.63%
#   ✅ Best model saved (99.63%)
# Epoch [7/25] Train Loss: 0.0018 Acc: 99.97% | Val Loss: 0.0319 Acc: 99.13%
# Epoch [8/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0292 Acc: 99.26%
# Epoch [9/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0279 Acc: 99.38%
# Epoch [10/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0271 Acc: 99.38%
# Epoch [11/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0268 Acc: 99.38%
# Epoch [12/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0265 Acc: 99.38%
# Epoch [13/25] Train Loss: 0.0000 Acc: 100.00% | Val Loss: 0.0262 Acc: 99.38%
#   ⏹ Early stopping at epoch 13
# Finished: ViT
#
# ==================================================
# Training: Swin
# ==================================================
# Epoch [1/25] Train Loss: 0.4476 Acc: 86.16% | Val Loss: 0.0585 Acc: 98.39%
#   ✅ Best model saved (98.39%)
# Epoch [2/25] Train Loss: 0.0387 Acc: 98.89% | Val Loss: 0.0537 Acc: 98.64%
#   ✅ Best model saved (98.64%)
# Epoch [3/25] Train Loss: 0.0235 Acc: 99.34% | Val Loss: 0.0652 Acc: 97.89%
# Epoch [4/25] Train Loss: 0.0274 Acc: 99.36% | Val Loss: 0.0933 Acc: 98.39%
# Epoch [5/25] Train Loss: 0.0061 Acc: 99.87% | Val Loss: 0.0125 Acc: 99.63%
#   ✅ Best model saved (99.63%)
# Epoch [6/25] Train Loss: 0.0012 Acc: 99.97% | Val Loss: 0.0149 Acc: 99.38%
# Epoch [7/25] Train Loss: 0.0335 Acc: 99.14% | Val Loss: 0.0394 Acc: 99.26%
# Epoch [8/25] Train Loss: 0.0308 Acc: 99.21% | Val Loss: 0.0380 Acc: 99.26%
# Epoch [9/25] Train Loss: 0.0179 Acc: 99.52% | Val Loss: 0.0256 Acc: 99.38%
# Epoch [10/25] Train Loss: 0.0033 Acc: 99.93% | Val Loss: 0.0258 Acc: 99.50%
# Epoch [11/25] Train Loss: 0.0021 Acc: 99.98% | Val Loss: 0.0236 Acc: 99.50%
# Epoch [12/25] Train Loss: 0.0003 Acc: 100.00% | Val Loss: 0.0248 Acc: 99.38%
#   ⏹ Early stopping at epoch 12
# Finished: Swin
#
# ==================================================
# Training: MobileViT
# ==================================================
# Epoch [1/25] Train Loss: 2.5349 Acc: 43.09% | Val Loss: 1.5037 Acc: 63.69%
#   ✅ Best model saved (63.69%)
# Epoch [2/25] Train Loss: 1.0697 Acc: 74.12% | Val Loss: 0.5075 Acc: 85.13%
#   ✅ Best model saved (85.13%)
# Epoch [3/25] Train Loss: 0.4287 Acc: 87.12% | Val Loss: 0.2937 Acc: 89.10%
#   ✅ Best model saved (89.10%)
# Epoch [4/25] Train Loss: 0.2462 Acc: 92.60% | Val Loss: 0.2241 Acc: 93.56%
#   ✅ Best model saved (93.56%)
# Epoch [5/25] Train Loss: 0.1478 Acc: 95.76% | Val Loss: 0.1492 Acc: 97.15%
# Epoch [6/25] Train Loss: 0.0024 Acc: 100.00% | Val Loss: 0.0368 Acc: 98.76%
# Epoch [7/25] Train Loss: 0.0011 Acc: 100.00% | Val Loss: 0.0406 Acc: 98.88%
# Epoch [8/25] Train Loss: 0.0008 Acc: 100.00% | Val Loss: 0.0425 Acc: 98.88%
# Epoch [9/25] Train Loss: 0.0050 Acc: 99.90% | Val Loss: 0.0437 Acc: 98.64%
# Epoch [10/25] Train Loss: 0.0063 Acc: 99.87% | Val Loss: 0.0599 Acc: 98.64%
#   ⏹ Early stopping at epoch 10
# Finished: EfficientViT

# %% [markdown]
# ### **7 - Model Evaluation**
# Evaluate each model on the held-out **test set** and generate a full `sklearn` classification report including per-class precision, recall, and F1-score.

# %%
def evaluate_model(name, model, test_loader):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(DEVICE)
            outputs = model(images)
            preds = outputs.argmax(1).cpu().numpy()
            y_true.extend(labels.numpy())
            y_pred.extend(preds)

    report = classification_report(
        y_true, y_pred,
        target_names=CLASS_NAMES,
        output_dict=True
    )
    return y_true, y_pred, report

results = {}
for name, model in models_to_train.items():
    print(f"Model: {name}...")
    y_true, y_pred, report = evaluate_model(name, model, test_loader)
    results[name] = {"y_true": y_true, "y_pred": y_pred, "report": report}
    print(f"  Accuracy: {report['accuracy']*100:.2f}%")
# Out:
# Model: ViT...
#   Accuracy: 99.26%
# Model: Swin...
#   Accuracy: 99.55%
# Model: MobileViT...
#   Accuracy: 99.11%
# Model: EfficientViT...
#   Accuracy: 99.11%

# %% [markdown]
# ### **8 - Model Visualization**
# Generate and save: summary table, accuracy curves, confusion matrices, and a grouped bar chart.

# %%
# Summary table
summary = []
for name, res in results.items():
    r = res["report"]
    summary.append({
        "Model":     name,
        "Accuracy":  round(r["accuracy"] * 100, 2),
        "Precision": round(r["weighted avg"]["precision"] * 100, 2),
        "Recall":    round(r["weighted avg"]["recall"] * 100, 2),
        "F1-Score":  round(r["weighted avg"]["f1-score"] * 100, 2),
    })

df = pd.DataFrame(summary).sort_values("Accuracy", ascending=False)
print("\n📊 Model Comparison on Test Set:")
print(df.to_string(index=False))
df.to_csv("/content/model_comparison.csv", index=False)
# Out:
# 📊 Model Comparison on Test Set:
#        Model  Accuracy  Precision  Recall  F1-Score
#         Swin     99.55      99.57   99.55     99.55
#          ViT     99.26      99.31   99.26     99.25
#    MobileViT     99.11      99.16   99.11     99.11
# EfficientViT     99.11      99.16   99.11     99.11

# %%
# Accuracy curves
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()
for i, (name, hist) in enumerate(histories.items()):
    axes[i].plot(hist["train_acc"], label="Train Acc")
    axes[i].plot(hist["val_acc"],   label="Val Acc")
    axes[i].set_title(f"{name}")
    axes[i].legend()
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel("Accuracy")
plt.tight_layout()
plt.savefig("/content/accuracy_curves.png", dpi=150)
plt.show()

# %%
# Confusion matrices
fig, axes = plt.subplots(2, 2, figsize=(24, 20))
axes = axes.flatten()
for i, (name, res) in enumerate(results.items()):
    cm = confusion_matrix(res["y_true"], res["y_pred"])
    sns.heatmap(cm, annot=True, fmt="d", ax=axes[i],
                xticklabels=CLASS_NAMES,
                yticklabels=CLASS_NAMES,
                cmap="Blues", cbar=False)
    axes[i].set_title(f"{name} - Confusion Matrix")
    axes[i].tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.savefig("/content/confusion_matrices.png", dpi=150)
plt.show()

# %%
# Bar chart
metrics = ["Accuracy", "Precision", "Recall", "F1-Score"]
x = np.arange(len(metrics))
width = 0.2

fig, ax = plt.subplots(figsize=(14, 6))
for i, (_, row) in enumerate(df.iterrows()):
    ax.bar(x + i * width, [row[m] for m in metrics], width, label=row["Model"])
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(metrics)
ax.set_ylabel("Score (%)")
ax.set_title("Model Performance Comparison")
ax.legend()
ax.set_ylim(50, 100)
plt.tight_layout()
plt.savefig("/content/model_bar_comparison.png", dpi=150)
plt.show()

# %% [markdown]
# ### **9 - Gradio UI**
# Launch an interactive web UI with four tabs:
# - **Single Model** — Detailed confidence scores and bar chart for one model
# - **Compare All Models** — Side-by-side predictions from all five models
# - **Model Info** — Parameter counts and class label reference
# - **Performance Results** — Test-set metrics table

# %%
def predict(image, model_name, top_k=5):
    if image is None:
        return None, None

    # Select model
    model = models_to_train[model_name]
    model.eval()

    # Preprocess image
    img_tensor = transform(image).unsqueeze(0).to(DEVICE)

    # Predict
    with torch.no_grad():
        outputs = model(img_tensor)
        probs = F.softmax(outputs, dim=1)[0]

    # Get top-k predictions
    top_probs, top_indices = torch.topk(probs, top_k)
    top_probs   = top_probs.cpu().numpy()
    top_indices = top_indices.cpu().numpy()

    top_classes = [CLASS_NAMES[i] for i in top_indices]

    # Build confidence dict for gradio label
    confidences = {cls: float(prob)
                   for cls, prob in zip(top_classes, top_probs)}

    # Build bar chart
    fig, ax = plt.subplots(figsize=(8, 4))
    colors = ["#2ecc71" if i == 0 else "#3498db"
              for i in range(len(top_classes))]
    bars = ax.barh(top_classes[::-1], top_probs[::-1] * 100, color=colors[::-1])
    ax.set_xlabel("Confidence (%)")
    ax.set_title(f"Top {top_k} Predictions — {model_name}")
    ax.set_xlim(0, 100)

    # Add value labels on bars
    for bar, prob in zip(bars, top_probs[::-1]):
        ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2,
                f"{prob*100:.1f}%", va="center", fontsize=10)

    plt.tight_layout()

    return confidences, fig

def predict_all_models(image):
    """Run all models and return combined comparison"""
    if image is None:
        return [None] * len(models_to_train)

    results = []
    for name, model in models_to_train.items():
        model.eval()
        img_tensor = transform(image).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            outputs = model(img_tensor)
            probs = F.softmax(outputs, dim=1)[0]

        top_probs, top_indices = torch.topk(probs, 3)
        top_probs   = top_probs.cpu().numpy()
        top_indices = top_indices.cpu().numpy()
        top_classes = [CLASS_NAMES[i] for i in top_indices]

        result = f"**{name}**\n"
        for cls, prob in zip(top_classes, top_probs):
            bar = "█" * int(prob * 20)
            result += f"  {cls}: {prob*100:.1f}% {bar}\n"
        results.append(result)

    return results


# Build Gradio UI
with gr.Blocks(theme=gr.themes.Soft(), title="Saudi Traffic Sign Classifier") as demo:

    gr.Markdown("""
    # 🚦 Saudi Traffic Sign Classifier
    ### Compare ViT, Swin, MobileViT, and EfficientViT
    Upload a traffic sign image to classify it using multiple transformer models.""")

    with gr.Tabs():

        # Tab 1: Single Model
        with gr.Tab("🔍 Single Model"):
            gr.Markdown("Test one model at a time with detailed confidence scores.")

            with gr.Row():
                with gr.Column(scale=1):
                    img_input = gr.Image(type="pil", label="Upload Traffic Sign")
                    model_dropdown = gr.Dropdown(
                        choices=list(models_to_train.keys()),
                        value=list(models_to_train.keys())[0],
                        label="Select Model"
                    )
                    top_k_slider = gr.Slider(
                        minimum=3, maximum=10, value=5, step=1,
                        label="Top-K Predictions"
                    )
                    predict_btn = gr.Button("Predict", variant="primary")

                with gr.Column(scale=2):
                    label_output = gr.Label(label="Predictions")
                    chart_output = gr.Plot(label="Confidence Chart")

            predict_btn.click(
                fn=predict,
                inputs=[img_input, model_dropdown, top_k_slider],
                outputs=[label_output, chart_output]
            )

        # Tab 2: Compare All Models
        with gr.Tab("⚡ Compare All Models"):
            gr.Markdown("Upload one image and compare predictions from all models simultaneously.")

            with gr.Row():
                with gr.Column(scale=1):
                    img_compare = gr.Image(type="pil", label="Upload Traffic Sign")
                    compare_btn = gr.Button("🔄 Compare All Models", variant="primary")

                with gr.Column(scale=2):
                    gr.Markdown("### Results")
                    model_outputs = [
                        gr.Markdown(label=name)
                        for name in models_to_train.keys()
                    ]

            compare_btn.click(
                fn=predict_all_models,
                inputs=[img_compare],
                outputs=model_outputs
            )

        # Tab 3: Model Info
        with gr.Tab("📊 Model Info"):
            gr.Markdown("### Model Summary")

            info_data = []
            for name, model in models_to_train.items():
                params = sum(p.numel() for p in model.parameters()) / 1e6
                trainable = sum(p.numel() for p in model.parameters()
                                if p.requires_grad) / 1e6
                info_data.append([name, f"{params:.1f}M", f"{trainable:.1f}M"])

            gr.Dataframe(
                value=info_data,
                headers=["Model", "Total Params", "Trainable Params"],
                label="Model Parameters"
            )

            gr.Markdown("### Class Labels")
            gr.Dataframe(
                value=[[i, cls] for i, cls in enumerate(CLASS_NAMES)],
                headers=["ID", "Class Name"],
                label="Saudi Traffic Sign Classes"
            )

        # Tab 4: Performance Results
        with gr.Tab("🏆 Performance Results"):
            gr.Markdown("### Test Set Performance")

            # Show results table if evaluation already done
            try:
                perf_data = []
                for name, res in results.items():
                    r = res["report"]
                    perf_data.append([
                        name,
                        f"{r['accuracy']*100:.2f}%",
                        f"{r['weighted avg']['precision']*100:.2f}%",
                        f"{r['weighted avg']['recall']*100:.2f}%",
                        f"{r['weighted avg']['f1-score']*100:.2f}%",
                    ])
                gr.Dataframe(
                    value=perf_data,
                    headers=["Model", "Accuracy", "Precision", "Recall", "F1-Score"],
                    label="Performance Comparison"
                )
            except:
                gr.Markdown("Run the evaluation step first to see results here.")

# Launch
demo.launch(share=True, debug=True)
# Out:
# The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://be241b36092c856dd9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://be241b36092c856dd9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://be241b36092c856dd9.gradio.live
